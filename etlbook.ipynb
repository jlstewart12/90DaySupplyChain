# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import pymongo
from splinter import Browser
from bs4 import BeautifulSoup as bs
from pprint import pprint
import time
from lxml import html

file_to_load = "Export_Sales_Full.csv"
exports_data = pd.read_csv(file_to_load, index_col=0)

# %%
exports_df = pd.DataFrame(exports_data)

# %%
exports_df.head()
# Out:
#         Week  Month  Year  Marketing Year    Country Commodity Commodity Type  \
# Date
# 1/6/00     1      1  2000            1999    ALGERIA      Corn            NaN
# 1/6/00     1      1  2000            1999    ALGERIA     Wheat          Durum
# 1/6/00     1      1  2000            1999    ALGERIA     Wheat            HRW
# 1/6/00     1      1  2000            1999  AUSTRALIA  Soybeans            NaN
# 1/6/00     1      1  2000            1999    BAHRAIN      Corn            NaN
#
#        Marketing Year Start or End         Unit  Weekly Exports CMY  \
# Date
# 1/6/00                         NaN  Metric Tons               20997
# 1/6/00                         NaN  Metric Tons               27500
# 1/6/00                         NaN  Metric Tons                   0
# 1/6/00                         NaN  Metric Tons                   0
# 1/6/00                         NaN  Metric Tons                   0
#
# ...

# %%
exports_df.dropna()
# Out:
#         Week  Month  Year  Marketing Year    Country Commodity Commodity Type  \
# Date
# 6/1/00    22      5  2000            1999    ALGERIA     Wheat          Durum
# 6/1/00    22      5  2000            1999    ALGERIA     Wheat            HRW
# 6/1/00    22      5  2000            2000    ALGERIA     Wheat            HRW
# 6/1/00    22      5  2000            1999  ARGENTINA     Wheat          White
# 6/1/00    22      5  2000            2000  ARGENTINA     Wheat          White
# ...      ...    ...   ...             ...        ...       ...            ...
# 6/6/19    22      6  2019            2019    UNKNOWN     Wheat            SRW
# 6/6/19    22      6  2019            2019    UNKNOWN     Wheat          White
# 6/6/19    22      6  2019            2019    VIETNAM     Wheat            HRS
# 6/6/19    22      6  2019            2019    VIETNAM     Wheat            HRW
# 6/6/19    22      6  2019            2019    VIETNAM     Wheat          White
#
# ...

# %%
html = exports_df.to_html()

# %%
 # executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)

# %%
# define url
# USDA_url = "https://agtransport.usda.gov/resource/wnn7-29tu.json"
#browser.visit(USDA_url)

# %%
# create beautiful soup object 
#html = browser.html
#soup = bs(html, 'html.parser')

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.exports_db
collection = db.Supply_Chain

# %%
db.collection.insert_many(exports_df.to_dict('records'))

# %%
import pandas as pd
from sodapy import Socrata
import pymongo

# %%
token = "Mrbrudsl7PrLCDmte8bddptk0"

# %%
client = Socrata("agtransport.usda.gov", token)

# %%
results = client.get("wnn7-29tu", limit = 100000)

# %%
exports_db = pd.DataFrame.from_records(results)

# %%
exports_db
# Out:
#                           date week month  year myear   country commodity  \
# 0      2020-03-26T00:00:00.000   12     3  2020  2019  HONDURAS     Wheat
# 1      2020-03-26T00:00:00.000   12     3  2020  2019   ECUADOR     Wheat
# 2      2020-03-26T00:00:00.000   12     3  2020  2019     SPAIN  Soybeans
# 3      2020-03-26T00:00:00.000   12     3  2020  2019   UNKNOWN     Wheat
# 4      2020-03-26T00:00:00.000   12     3  2020  2019     JAPAN     Wheat
# ...                        ...  ...   ...   ...   ...       ...       ...
# 99995  2012-01-12T00:00:00.000    2     1  2012  2011    CANADA     Wheat
# 99996  2012-01-12T00:00:00.000    2     1  2012  2011     CHILE     Wheat
# 99997  2012-01-12T00:00:00.000    2     1  2012  2011     BURMA     Wheat
# 99998  2012-01-12T00:00:00.000    2     1  2012  2011     BURMA     Wheat
# 99999  2012-01-12T00:00:00.000    2     1  2012  2011     BURMA     Wheat
#
#         type         unit wkexportscmy  ... outsalescmy grosalescmy  \
# ...

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.exports_db
collection = db.Supply_Chain

# %%
db.collection.insert_many(exports_db.to_dict('records'))
